# %%
import os
import json

def rename_key(menu):
    i = 0
    for line in menu:
        if "price" in line and "itemsubtotal" not in line:
            line["itemsubtotal"] = line.pop("price")
            print(line)
            i += 1
    return i

        


file_path = "C:\\Users\\user\\OneDrive\\Documents\\MONASH SEM6\\FIT3164 - FYP\\JPG_BATCH_3\\edited.json"
jsons = []

with open(file_path, 'r', encoding='utf-8') as f:
    for line in f:
        try:
            data = json.loads(line)
        except json.JSONDecodeError:
            print(f"Skipping invalid JSON")
            print(line)

with open(file_path, 'r', encoding='utf-8') as f:
    edit_counts = 0
    for line in f:
        data = json.loads(line)
        menu = None
        menu = data["ground_truth"]["gt_parse"]["menu"]
        if menu:
            edit_counts += rename_key(menu)
            jsons.append(data)
        else:
            print("THIS LINE DOESNT HAVE MENU")
            print(data)
print(str(edit_counts)+ " lines edited")
print(jsons)
# Out:
# 0 lines edited
# [{'id': 184, 'file_name': '0475.jpg', 'ground_truth': {'gt_parse': {'merchant': 'AELDO RADO SDN. BHD.', 'date': '30-12-2020', 'recipient': 'Nippo Mechatronics (M) Sdn. Bhd.', 'menu': [{'nm': 'Nylon Bush M16 (12pcs/box)', 'cnt': '2', 'num': 'APL16-ORANGE', 'unitprice': '158.00', 'discountprice': '10.00', 'itemsubtotal': '306.00'}], 'total': {'total_price': '306.00'}}}}, {'id': 185, 'file_name': '0479.jpg', 'ground_truth': {'gt_parse': {'merchant': 'AELDO RADO SDN. BHD.', 'date': '04-01-2021', 'recipient': 'Ingress Precision Sdn Bhd', 'menu': [{'nm': 'Tapping Bil M5 x 0.8', 'cnt': '60', 'num': 'AYMW-05.0X0.8PO', 'unitprice': '25.80', 'discountprice': '0.00', 'itemsubtotal': '1,548.00'}], 'total': {'total_price': '1,548.00'}}}}, {'id': 186, 'file_name': '0498.jpg', 'ground_truth': {'gt_parse': {'merchant': 'PP FURNITURE ENTERRISE', 'date': '1-2-2020', 'recipient': '013 7848098', 'menu': [{'nm': "TABEL 5'' Azri's Table", 'itemsubtotal': '120'}], 'total': {'total_price': '120'}}}}, {'id': 187, 'file_name': '0437.jpg', 'ground_truth': {'gt_parse': {'merchant': 'AVISION TECHNOLOGY SDN BHD', 'date': '05/04/2024', 'recipient': 'Panasonic Appliances Air-Conditioning Malaysia Sdn Bhd', 'menu': [{'nm': 'License Key Installation and Configuration for MyKad', 'cnt': '3', 'unitprice': '180.00', 'itemsubtotal': '540.00'}], 'subtotal': {'subtotal_price': '540.00', 'etc': '0.00'}, 'total': {'total_price': '540.00'}}}}, {'id': 188, 'file_name': '0458.jpg', 'ground_truth': {'gt_parse': {'merchant': 'AELDO RADO SDN. BHD.', 'date': '28-12-2023', 'recipient': 'Toto Malaysia Sdn. Bhd.', 'menu': [{'nm': 'SONIC JSN PU Tubing 12mm x 8mm x 100 Meter (Clear)', 'cnt': '2', 'num': 'LZE-PU1208CLEAR', 'unitprice': '510.00', 'discountprice': '0.00', 'itemsubtotal': '1,020.00'}], 'total': {'total_price': '1,020.00'}}}}, {'id': 189, 'file_name': '0468.jpg', 'ground_truth': {'gt_parse': {'merchant': 'PIRAMID PRESTIJ SDN BHD', 'date': '10/12/2020', 'recipient': 'AMBANG PIRAMID SDN BHD', 'menu': [{'nm': 'MO-PIN BUSH - 70 X 50 X 98 SHORE 95 - YELLOW', 'cnt': '20.00', 'unitprice': '21.00', 'itemsubtotal': '420.00'}, {'nm': '70 X 35 X 85MM(H) SHORE 50 - ORANGE', 'cnt': '2.00', 'unitprice': '42.00', 'itemsubtotal': '84.00'}, {'nm': '55 X 35 X 110MM (H) SHORE 50 - ORANGE', 'cnt': '2.00', 'unitprice': '42.00', 'itemsubtotal': '84.00'}, {'nm': 'POLYURETHANE ROLLER - 110MM OD X 100MM(L) X M31MM BORE', 'cnt': '3.00', 'unitprice': '129.00', 'itemsubtotal': '387.00'}, {'nm': '82 X 63 X 1500MM L SKY BLUE', 'cnt': '16.00', 'unitprice': '456.00', 'itemsubtotal': '7,296.00'}, {'nm': '82 X 63 X 1800MM L SKY BLUE', 'cnt': '3.00', 'unitprice': '576.00', 'itemsubtotal': '1,728.00'}], 'subtotal': {'subtotal_price': '9,999.00', 'tax_price': '0.00'}, 'total': {'total_price': '9,999.00'}}}}, {'id': 190, 'file_name': '0441.jpg', 'ground_truth': {'gt_parse': {'merchant': 'V FIVE PRINTERS', 'date': '30/06/2023', 'recipient': 'YCH PRINTING & MEDIA SDN BHD', 'menu': [{'nm': 'RECOND MITSUBISHI DAIYA PRINTING MACHINE SERIAL NUMBER: 1F535 * C/W NECESSARY SPARE PART', 'cnt': '1', 'unitprice': '180,000.000', 'itemsubtotal': '180,000.00'}], 'total': {'total_price': '180,000.00'}}}}, {'id': 191, 'file_name': '0487.jpg', 'ground_truth': {'gt_parse': {'merchant': 'YCH Printing & Media Sdn Bhd', 'date': '05/01/2021', 'recipient': 'ROCHE DIAGNOSTICS (M) SDN BHD', 'menu': [{'nm': 'NAME CARD - ALAN K.L. WONG - J/S 54376', 'cnt': '2', 'unitprice': '20.000', 'itemsubtotal': '40.00'}, {'nm': 'NAME CARD - TEOH SUE NEE - J/S 54376', 'cnt': '2', 'unitprice': '90.000', 'itemsubtotal': '40.00'}], 'subtotal': {'subtotal_price': '80.00', 'tax_price': '0.00'}, 'total': {'total_price': '80.00'}}}}, {'id': 192, 'file_name': '0493.jpg', 'ground_truth': {'gt_parse': {'merchant': 'DIVERSIFIED ENGINEERING & CONSTRUCTION SDN BHD', 'date': '30/11/2021', 'recipient': 'Gas Malaysia Distribution Sdn Bhd', 'menu': [{'nm': 'Payment Schedule No.9 EPCC Of NGDS To Kinta Vallev FL ST 2/19.Tasek Ind.Area.Perak. (Too Glove Sdn Bhd)',  ...

# %% [markdown]
# changing the groundtruth into strings

# %%
import os
import json

file_path = "C:\\Users\\user\\OneDrive\\Documents\\MONASH SEM6\\FIT3164 - FYP\\JPG_BATCH_3"
json_files = [f for f in os.listdir(file_path) if f.lower().endswith('.json')]
for j in json_files:
    jsons = []
    print(j)
    json_path = os.path.join(file_path, j)
    with open(json_path, 'r', encoding='utf-8') as f:
        for line in f:
            data = json.loads(line)
            data["ground_truth"] = json.dumps(data["ground_truth"])
            jsons.append(data)

    output_filename = j[:-5] + "_edited.json"
    output_file = os.path.join(file_path, output_filename)
    with open(output_file, 'w', encoding='utf-8') as out_f:
        for obj in jsons:
            out_f.write(json.dumps(obj) + '\n')
    print(f"saved edited file to {output_file}")
# Out:
# 1-80(new).json
# saved edited file to C:\Users\user\OneDrive\Documents\MONASH SEM6\FIT3164 - FYP\New folder\1-80(new)_edited.json
# 161-240.json
# saved edited file to C:\Users\user\OneDrive\Documents\MONASH SEM6\FIT3164 - FYP\New folder\161-240_edited.json
# 241-322(new).json
# saved edited file to C:\Users\user\OneDrive\Documents\MONASH SEM6\FIT3164 - FYP\New folder\241-322(new)_edited.json
# 323-425.json
# saved edited file to C:\Users\user\OneDrive\Documents\MONASH SEM6\FIT3164 - FYP\New folder\323-425_edited.json
# 501-550(new).json
# saved edited file to C:\Users\user\OneDrive\Documents\MONASH SEM6\FIT3164 - FYP\New folder\501-550(new)_edited.json
# 551-600.json
# saved edited file to C:\Users\user\OneDrive\Documents\MONASH SEM6\FIT3164 - FYP\New folder\551-600_edited.json
# 81-160.json
# saved edited file to C:\Users\user\OneDrive\Documents\MONASH SEM6\FIT3164 - FYP\New folder\81-160_edited.json
